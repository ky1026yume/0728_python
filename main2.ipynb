# %%
import pandas as pd
member_df = pd.read_csv("Member_Data.csv")
sales_df = pd.read_csv("Sales_Data.csv")

# %%
sales_df.head()
# Out:
#    Transaction_ID Transaction_Date  Member_ID  Product_ID  Store_ID  Quantity  \
# 0               1    2024/5/1 0:00         21          25        12         3
# 1               2    2024/5/1 2:55        107          23        17         1
# 2               3    2024/5/1 5:51        117          24         6         3
# 3               4    2024/5/1 8:47        124          38         1         3
# 4               5   2024/5/1 11:43        281          28         5         4
#
#    Amount
# 0    5820
# 1     640
# 2    1270
# 3    5980
# 4    9390

# %%
sales_df.tail()
# Out:
#      Transaction_ID Transaction_Date  Member_ID  Product_ID  Store_ID  \
# 995             996  2024/8/30 12:16        213          33        15
# 996             997  2024/8/30 15:12         62          49        19
# 997             998  2024/8/30 18:08         49          12        11
# 998             999  2024/8/30 21:04        127          11        15
# 999            1000   2024/8/31 0:00        223           5        12
#
#      Quantity  Amount
# 995         3    8400
# 996         3    3930
# 997         4    2530
# 998         3    4160
# 999         2    7530

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    1000 non-null   int64
#  1   Transaction_Date  1000 non-null   object
#  2   Member_ID         1000 non-null   int64
#  3   Product_ID        1000 non-null   int64
#  4   Store_ID          1000 non-null   int64
#  5   Quantity          1000 non-null   int64
#  6   Amount            1000 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 54.8+ KB

# %%
sales_df["Transaction_ID"] = sales_df["Transaction_ID"].astype("string")
sales_df["Member_ID"] = sales_df["Member_ID"].astype("string")
sales_df["Product_ID"] = sales_df["Product_ID"].astype("string")
sales_df["Store_ID"] = sales_df["Store_ID"].astype("string")

member_df["Member_ID"] = member_df["Member_ID"].astype("string")

# %%
sales_df["Transaction_Date"] = pd.to_datetime(sales_df["Transaction_Date"])

# %%
sales_df.describe()
# Out:
#                     Transaction_Date     Quantity        Amount
# count                           1000  1000.000000   1000.000000
# mean   2024-06-30 23:59:30.299999744     2.551000   5338.650000
# min              2024-05-01 00:00:00     1.000000    510.000000
# 25%              2024-05-31 11:59:15     2.000000   3022.500000
# 50%              2024-06-30 23:59:30     3.000000   5250.000000
# 75%              2024-07-31 11:59:45     4.000000   7752.500000
# max              2024-08-31 00:00:00     4.000000  10000.000000
# std                              NaN     1.103003   2778.234487

# %%
sales_df.rename(columns={"Amount": "Sales_Amount"})
sales_df.head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount
# 0    5820
# 1     640
# 2    1270
# 3    5980
# 4    9390

# %%
sales_df["Amount"] = sales_df["Amount"].round(-2)
sales_df.head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount
# 0    5800
# 1     600
# 2    1300
# 3    6000
# 4    9400

# %%
sales_df.query("Amount > 5000").head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
# 5              6 2024-05-01 14:39:00       292         21       14         4
# 6              7 2024-05-01 17:35:00       203         43        5         3
#
#    Amount
# 0    5800
# 3    6000
# 4    9400
# 5    8700
# 6    9800

# %%
member_df.query("30 < Age < 50 ").head()
# Out:
#    Member_ID  Gender  Age  Days_Since_Registration
# 3          4  Female   49                     1881
# 8          9    Male   48                     1640
# 9         10  Female   48                     1317
# 12        13    Male   41                     1855
# 13        14    Male   33                      928

# %%
sales_df.query("Transaction_Date >= '2024-08-01'")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 754            755 2024-08-01 01:55:00       226         17       14
# 755            756 2024-08-01 04:51:00       131         18       18
# 756            757 2024-08-01 07:47:00        76         45       13
# 757            758 2024-08-01 10:42:00       286         29       11
# 758            759 2024-08-01 13:38:00       277         20       16
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 754         4    8600
# 755         3    1000
# 756         3    1900
# 757         1    4400
# ...

# %%
sales_df.query("(Store_ID =='1' or Store_ID =='3') and Amount >= 5000").head()
# Out:
#    Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 3               4 2024-05-01 08:47:00       124         38        1         3
# 7               8 2024-05-01 20:30:00        51         18        1         4
# 17             18 2024-05-03 01:49:00       156          3        1         3
# 61             62 2024-05-08 10:47:00        50         38        3         4
# 65             66 2024-05-08 22:30:00        60         49        3         2
#
#     Amount
# 3     6000
# 7     5500
# 17    7600
# 61    6500
# 65    5800

# %%
sales_df.query("Product_ID in  ['10','20','30']").head()
# Out:
#    Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 13             14 2024-05-02 14:06:00        52         30        2         1
# 41             42 2024-05-06 00:10:00        47         20       12         1
# 44             45 2024-05-06 08:57:00       277         10       10         4
# 69             70 2024-05-09 10:14:00       164         30        9         3
# 84             85 2024-05-11 06:11:00       138         30        2         3
#
#     Amount
# 13    8600
# 41    3100
# 44    6900
# 69    4600
# 84    1800

# %%
sales_df.query("Product_ID not in  ['10','20','30']").head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount
# 0    5800
# 1     600
# 2    1300
# 3    6000
# 4    9400

# %%
mode_sales =  sales_df["Quantity"].mode()[0]
sales_df.query("Quantity == @mode_sales and Store_ID == '3'").head()
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 43              44 2024-05-06 06:01:00       118         29        3
# 61              62 2024-05-08 10:47:00        50         38        3
# 109            110 2024-05-14 07:28:00       229         49        3
# 383            384 2024-06-16 18:32:00       269         44        3
# 446            447 2024-06-24 11:11:00       108         13        3
#
#      Quantity  Amount
# 43          4    4800
# 61          4    6500
# 109         4    9800
# 383         4    4300
# 446         4    7800

# %%
q1 = sales_df["Amount"].quantile(0.25)
q3 = sales_df["Amount"].quantile(0.75)

sales_df.query("@q1 < Amount < @q3")
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 3                4 2024-05-01 08:47:00       124         38        1
# 7                8 2024-05-01 20:30:00        51         18        1
# 10              11 2024-05-02 05:18:00       141         45        9
# 11              12 2024-05-02 08:14:00       275          9       19
# ..             ...                 ...       ...        ...      ...
# 991            992 2024-08-30 00:33:00       258         19       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 996            997 2024-08-30 15:12:00        62         49       19
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount
# 0           3    5800
# 3           3    6000
# 7           4    5500
# 10          4    6700
# ...

# %%
print(sales_df["Product_ID"].nunique())
print(sales_df["Store_ID"].nunique())
# Out:
# 50
# 20

# %%
sales_df.groupby("Product_ID")["Amount"].sum().head()
# Out:
# Product_ID
# 1     121600
# 10     92100
# 11    138700
# 12     63900
# 13    139300
# Name: Amount, dtype: int64

# %%
sales_df.groupby("Product_ID")["Quantity"].median().head()
# Out:
# Product_ID
# 1     2.0
# 10    3.0
# 11    3.0
# 12    3.0
# 13    2.0
# Name: Quantity, dtype: float64

# %%
sales_df.groupby("Store_ID")["Amount"].mean().head()
# Out:
# Store_ID
# 1     5873.333333
# 10    5301.923077
# 11    4868.000000
# 12    5602.272727
# 13    5815.254237
# Name: Amount, dtype: float64

# %%
member_df.groupby("Gender")["Age"].mean().head()
# Out:
# Gender
# Female    48.945205
# Male      53.259740
# Name: Age, dtype: float64

# %%
sales_df.groupby("Member_ID")["Amount"].mean().head()
# Out:
# Member_ID
# 1      5000.000000
# 10     6350.000000
# 100    7166.666667
# 101    6100.000000
# 102    4275.000000
# Name: Amount, dtype: float64

# %%
sales_df["Transaction_Date_new"] = sales_df["Transaction_Date"].dt.date
sales_df.groupby("Transaction_Date_new")["Amount"].sum().head()
# Out:
# Transaction_Date_new
# 2024-05-01    55100
# 2024-05-02    47800
# 2024-05-03    52000
# 2024-05-04    38800
# 2024-05-05    47400
# Name: Amount, dtype: int64

# %%
sales_df["Transaction_Date_new"] = sales_df["Transaction_Date"].dt.date
sales_df.groupby("Transaction_Date_new")["Amount"].sum().reset_index().sort_values("Amount",ascending=True).head()
# Out:
#     Transaction_Date_new  Amount
# 122           2024-08-31    7500
# 51            2024-06-21   24100
# 20            2024-05-21   25200
# 114           2024-08-23   28200
# 68            2024-07-08   28900

# %%
sales_df["Transaction_Date_month"] = sales_df["Transaction_Date"].dt.month
sales_df.groupby("Transaction_Date_month")["Amount"].sum().reset_index()
# Out:
#    Transaction_Date_month   Amount
# 0                       5  1374500
# 1                       6  1282200
# 2                       7  1355700
# 3                       8  1325700

# %%
sales_ef_diff = sales_df.groupby("Transaction_Date_month")["Amount"].sum().reset_index()
sales_ef_diff["diff"] = sales_ef_diff["Amount"].diff()
sales_ef_diff.head()
# Out:
#    Transaction_Date_month   Amount     diff
# 0                       5  1374500      NaN
# 1                       6  1282200 -92300.0
# 2                       7  1355700  73500.0
# 3                       8  1325700 -30000.0

# %%
sales_df["Transaction_Date_monday"] = sales_df["Transaction_Date"].dt.weekday
sales_df.groupby("Transaction_Date_monday")["Amount"].sum().head()
# Out:
# Transaction_Date_monday
# 0    718500
# 1    722500
# 2    842100
# 3    791900
# 4    745700
# Name: Amount, dtype: int64

# %%
sales_df["Transaction_Date_week"] = sales_df["Transaction_Date"].dt.to_period("W")
sales_df.groupby("Transaction_Date_week")["Amount"].sum().head()
# Out:
# Transaction_Date_week
# 2024-04-29/2024-05-05    241100
# 2024-05-06/2024-05-12    311300
# 2024-05-13/2024-05-19    304900
# 2024-05-20/2024-05-26    309600
# 2024-05-27/2024-06-02    290600
# Freq: W-SUN, Name: Amount, dtype: int64

# %%
sales_df["Transaction_Date_week"] = sales_df["Transaction_Date"].dt.to_period("W")
pct = sales_df.groupby("Transaction_Date_week")["Amount"].sum().reset_index()
pct["Amount"].pct_change()*100
# Out:
# 0           NaN
# 1     29.116549
# 2     -2.055895
# 3      1.541489
# 4     -6.136951
# 5      7.639367
# 6     -4.060102
# 7     -6.064645
# 8      7.981554
# 9      5.059133
# 10   -10.068793
# 11     7.753825
# 12    -7.228138
# 13     9.982609
# 14   -11.796331
# 15    23.305844
# 16   -10.846176
# 17   -24.657534
# Name: Amount, dtype: float64

# %%
sales_df.drop(columns=["Transaction_Date_week","Transaction_Date_monday"])
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month
# 0           3    5800           2024-05-01                       5
# ...

# %%
tu = sales_df.query("Amount > 1000")
tu.groupby("Store_ID")["Amount"].sum().head()
tu.groupby("Product_ID")["Amount"].sum().head()
# Out:
# Product_ID
# 1     121000
# 10     92100
# 11    138700
# 12     62400
# 13    135900
# Name: Amount, dtype: int64

# %%
tutu = sales_df.groupby("Store_ID")["Amount"].sum().reset_index()
tutu.query("Amount >= 300000")
# Out:
#    Store_ID  Amount
# 4        13  343100
# 6        15  357500
# 8        17  326200
# 18        8  331600

# %%
sales_df.groupby("Member_ID")["Transaction_ID"].count().head()
# Out:
# Member_ID
# 1      2
# 10     4
# 100    3
# 101    6
# 102    4
# Name: Transaction_ID, dtype: int64

# %%
tututu = sales_df.groupby("Member_ID")["Transaction_ID"].count().reset_index().head()
tututu.query("Transaction_ID > 2")
# Out:
#   Member_ID  Transaction_ID
# 1        10               4
# 2       100               3
# 3       101               6
# 4       102               4

# %%
bins = [min(member_df["Age"])-1,30,50,65,max(member_df["Age"])]
labels = ["A","B","C","D"]
member_df["age_group"] = pd.cut(member_df["Age"],bins=bins,labels=labels)
member_df.head()
member_df.groupby("age_group")["Member_ID"].count().head()
# Out:
# C:\Users\rainm\AppData\Local\Temp\ipykernel_24152\2436008630.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   member_df.groupby("age_group")["Member_ID"].count().head()
# age_group
# A     49
# B    103
# C     59
# D     89
# Name: Member_ID, dtype: int64

# %%
bins = [min(member_df["Days_Since_Registration"])-1,365,710,max(member_df["Days_Since_Registration"])]
labels = ["A","B","C"]
member_df["age_group2"] = pd.cut(member_df["Days_Since_Registration"],bins=bins,labels=labels)
member_df.groupby("age_group2")["Member_ID"].count().head()
# Out:
# C:\Users\rainm\AppData\Local\Temp\ipykernel_24152\1163296932.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   member_df.groupby("age_group2")["Member_ID"].count().head()
# age_group2
# A     52
# B     50
# C    198
# Name: Member_ID, dtype: int64

# %%
kishi_df = pd.concat([member_df,sales_df],axis=1)
kishi_df.head()
# Out:
#   Member_ID  Gender   Age  Days_Since_Registration age_group age_group2  \
# 0         1    Male  69.0                    730.0         D          C
# 1         2  Female  18.0                    958.0         A          C
# 2         3    Male  66.0                   1976.0         D          C
# 3         4  Female  49.0                   1881.0         B          C
# 4         5    Male  69.0                    269.0         D          A
#
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount Transaction_Date_new  Transaction_Date_month  \
# ...

# %%
kishi_df_df = sales_df.merge(member_df,on="Member_ID")
kishi_df_df
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# ..             ...                 ...       ...        ...      ...
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 0           3    5800           2024-05-01                       5
# ...

# %%
kishi_df.groupby("Gender")["Amount"].mean()
# Out:
# Gender
# Female    5466.438356
# Male      5374.675325
# Name: Amount, dtype: float64

# %%
kishi_df_df.groupby("Gender")["Quantity"].mean()
# Out:
# Gender
# Female    2.529293
# Male      2.572277
# Name: Quantity, dtype: float64

# %%
kishi_df_df.groupby(["Gender","Store_ID"])["Transaction_ID"].count()
# Out:
# Gender  Store_ID
# Female  1           19
#         10          19
#         11          24
#         12          27
#         13          26
#         14          27
#         15          30
#         16          24
#         17          34
#         18          22
#         19          23
#         2           19
#         20          23
#         3           24
#         4           29
#         5           25
#         6           28
#         7           16
#         8           34
#         9           22
# Male    1           26
#         10          33
#         11          26
#         12          17
#         13          33
#         14          18
#         15          34
#         16          27
#         17          35
#         18          26
#         19          24
#         2           23
#         20          29
#         3           27
#         4           12
#         5           19
#         6           26
#         7           23
#         8           27
# ...

# %%
store_df = sales_df.query("Store_ID  in ['1','5','9']")
store_df.groupby("Store_ID")["Quantity"].sum()
# Out:
# Store_ID
# 1    111
# 5    125
# 9    112
# Name: Quantity, dtype: int64

# %%
saido = sales_df[sales_df["Transaction_Date"] > sales_df["Transaction_Date"].max()-pd.Timedelta(days=10)]
saido.groupby("Transaction_Date")["Amount"].sum()
# Out:
# Transaction_Date
# 2024-08-21 02:35:00     6100
# 2024-08-21 05:31:00     1900
# 2024-08-21 08:27:00     4300
# 2024-08-21 11:23:00     9100
# 2024-08-21 14:19:00    10000
#                        ...
# 2024-08-30 12:16:00     8400
# 2024-08-30 15:12:00     3900
# 2024-08-30 18:08:00     2500
# 2024-08-30 21:04:00     4200
# 2024-08-31 00:00:00     7500
# Name: Amount, Length: 82, dtype: int64

# %%
saito= sales_df["Member_ID"]
saito.head()
# Out:
# 0     21
# 1    107
# 2    117
# 3    124
# 4    281
# Name: Member_ID, dtype: string

# %%
sales_df.groupby("Member_ID")["Amount"].sum().nlargest(5)
# Out:
# Member_ID
# 49     55200
# 260    55100
# 149    51300
# 154    51200
# 158    50200
# Name: Amount, dtype: int64

# %%
sales_df.groupby("Member_ID")["Transaction_Date"].max()
# Out:
# Member_ID
# 1     2024-08-24 00:56:00
# 10    2024-06-26 04:13:00
# 100   2024-08-08 00:59:00
# 101   2024-07-27 16:24:00
# 102   2024-08-09 03:21:00
#               ...
# 95    2024-06-22 18:09:00
# 96    2024-05-28 23:10:00
# 97    2024-07-23 09:49:00
# 98    2024-07-19 03:14:00
# 99    2024-07-20 05:37:00
# Name: Transaction_Date, Length: 288, dtype: datetime64[ns]

# %%
sales_df.groupby("Member_ID")["Transaction_Date"].min()
# Out:
# Member_ID
# 1     2024-08-04 20:46:00
# 10    2024-05-07 02:32:00
# 100   2024-05-08 19:34:00
# 101   2024-05-23 17:09:00
# 102   2024-05-13 10:57:00
#               ...
# 95    2024-05-27 06:09:00
# 96    2024-05-28 23:10:00
# 97    2024-06-01 09:14:00
# 98    2024-07-17 21:56:00
# 99    2024-05-31 12:43:00
# Name: Transaction_Date, Length: 288, dtype: datetime64[ns]

# %%
df_tmp = sales_df.groupby("Member_ID").agg({"Transaction_Date":["max", "min"]}).reset_index()
df_tmp.columns = ["Member_ID","Transaction_Max","Transaction_Min"]
df_tmp.query("Transaction_Max != Transaction_Min")
# Out:
#     Member_ID     Transaction_Max     Transaction_Min
# 0           1 2024-08-24 00:56:00 2024-08-04 20:46:00
# 1          10 2024-06-26 04:13:00 2024-05-07 02:32:00
# 2         100 2024-08-08 00:59:00 2024-05-08 19:34:00
# 3         101 2024-07-27 16:24:00 2024-05-23 17:09:00
# 4         102 2024-08-09 03:21:00 2024-05-13 10:57:00
# ..        ...                 ...                 ...
# 282        93 2024-08-29 15:45:00 2024-08-16 14:09:00
# 283        95 2024-06-22 18:09:00 2024-05-27 06:09:00
# 285        97 2024-07-23 09:49:00 2024-06-01 09:14:00
# 286        98 2024-07-19 03:14:00 2024-07-17 21:56:00
# 287        99 2024-07-20 05:37:00 2024-05-31 12:43:00
#
# [252 rows x 3 columns]

# %%
sales_df["Member_ID"].dtype
sales_df[sales_df["Member_ID"].str.contains("2")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# 6                7 2024-05-01 17:35:00       203         43        5
# ..             ...                 ...       ...        ...      ...
# 994            995 2024-08-30 09:20:00       235          8       12
# 995            996 2024-08-30 12:16:00       213         33       15
# 996            997 2024-08-30 15:12:00        62         49       19
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 0           3    5800           2024-05-01                       5
# ...

# %%
sales_df["Product_ID"].dtype
sales_df[sales_df["Product_ID"].str.startswith("1")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 7                8 2024-05-01 20:30:00        51         18        1
# 21              22 2024-05-03 13:32:00       106         15       15
# 25              26 2024-05-04 01:16:00        77         11       18
# 38              39 2024-05-05 15:22:00       263          1        9
# 39              40 2024-05-05 18:18:00       172          1       17
# ..             ...                 ...       ...        ...      ...
# 991            992 2024-08-30 00:33:00       258         19       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 993            994 2024-08-30 06:24:00       268         16        7
# 997            998 2024-08-30 18:08:00        49         12       11
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 7           4    5500           2024-05-01                       5
# ...

# %%
sales_df[sales_df["Product_ID"].str.endswith("1")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 5                6 2024-05-01 14:39:00       292         21       14
# 22              23 2024-05-03 16:28:00       158         41       14
# 25              26 2024-05-04 01:16:00        77         11       18
# 38              39 2024-05-05 15:22:00       263          1        9
# 39              40 2024-05-05 18:18:00       172          1       17
# ..             ...                 ...       ...        ...      ...
# 920            921 2024-08-21 08:27:00        43         41        5
# 934            935 2024-08-23 01:29:00        41          1       13
# 962            963 2024-08-26 11:33:00       127          1        6
# 978            979 2024-08-28 10:27:00        51         31        5
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 5           4    8700           2024-05-01                       5
# ...

# %%
sales_df[sales_df["Transaction_ID"].str.endswith(("1","3","5","7","9"))]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 0                1 2024-05-01 00:00:00        21         25       12
# 2                3 2024-05-01 05:51:00       117         24        6
# 4                5 2024-05-01 11:43:00       281         28        5
# 6                7 2024-05-01 17:35:00       203         43        5
# 8                9 2024-05-01 23:26:00       271         36       18
# ..             ...                 ...       ...        ...      ...
# 990            991 2024-08-29 21:37:00       296         16       14
# 992            993 2024-08-30 03:29:00        81         18       13
# 994            995 2024-08-30 09:20:00       235          8       12
# 996            997 2024-08-30 15:12:00        62         49       19
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 0           3    5800           2024-05-01                       5
# ...

# %%
sales_df[sales_df["Member_ID"].str.len() == 3]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 4                5 2024-05-01 11:43:00       281         28        5
# 5                6 2024-05-01 14:39:00       292         21       14
# ..             ...                 ...       ...        ...      ...
# 993            994 2024-08-30 06:24:00       268         16        7
# 994            995 2024-08-30 09:20:00       235          8       12
# 995            996 2024-08-30 12:16:00       213         33       15
# 998            999 2024-08-30 21:04:00       127         11       15
# 999           1000 2024-08-31 00:00:00       223          5       12
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 1           1     600           2024-05-01                       5
# ...

# %%
sales_df[sales_df["Member_ID"].str.contains("13")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 19              20 2024-05-03 07:41:00       136         28       20
# 26              27 2024-05-04 04:12:00       132         48       10
# 84              85 2024-05-11 06:11:00       138         30        2
# 112            113 2024-05-14 16:15:00       136         45       15
# 117            118 2024-05-15 06:55:00       130         34       11
# 130            131 2024-05-16 21:01:00       130         28       14
# 151            152 2024-05-19 10:34:00       136         17        3
# 198            199 2024-05-25 04:19:00       134          7       17
# 205            206 2024-05-26 00:50:00       130         17       20
# 238            239 2024-05-30 01:33:00       130         47       16
# 244            245 2024-05-30 19:08:00       130         49       14
# 279            280 2024-06-04 01:43:00       133          3        1
# 287            288 2024-06-05 01:10:00       138         38        1
# ...

# %%
sales_df[sales_df["Member_ID"].str.contains("^1")]
# Out:
#     Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  \
# 1                2 2024-05-01 02:55:00       107         23       17
# 2                3 2024-05-01 05:51:00       117         24        6
# 3                4 2024-05-01 08:47:00       124         38        1
# 10              11 2024-05-02 05:18:00       141         45        9
# 15              16 2024-05-02 19:57:00       157         34        7
# ..             ...                 ...       ...        ...      ...
# 979            980 2024-08-28 13:22:00       118          4       17
# 985            986 2024-08-29 06:58:00       155          8        6
# 986            987 2024-08-29 09:53:00       117          7       18
# 989            990 2024-08-29 18:41:00       166         50       17
# 998            999 2024-08-30 21:04:00       127         11       15
#
#      Quantity  Amount Transaction_Date_new  Transaction_Date_month  \
# 1           1     600           2024-05-01                       5
# ...

# %%
saihin = sales_df.groupby("Product_ID")["Quantity"].agg(lambda x :x.mode()[0]).reset_index()
saihin.query("Quantity >= 3")
# Out:
#    Product_ID  Quantity
# 2          11         3
# 3          12         3
# 4          13         4
# 6          15         4
# 7          16         4
# 9          18         3
# 12         20         4
# 14         22         3
# 17         25         3
# 20         28         4
# 23         30         3
# 24         31         4
# 25         32         3
# 26         33         3
# 27         34         3
# 28         35         3
# 29         36         4
# 30         37         4
# 36         42         4
# 37         43         3
# 43         49         3
# 44          5         3
# 46          6         4

# %%
saihin = sales_df.groupby("Product_ID")["Quantity"].agg(lambda x :x.mode()[0]).reset_index()
saihin[saihin["Quantity"] == saihin["Quantity"].max()]
# Out:
#    Product_ID  Quantity
# 4          13         4
# 6          15         4
# 7          16         4
# 12         20         4
# 20         28         4
# 24         31         4
# 29         36         4
# 30         37         4
# 36         42         4
# 46          6         4

# %%
sales_df.groupby("Store_ID")["Amount"].var().sort_values(ascending=False)
# Out:
# Store_ID
# 11    9.015690e+06
# 7     8.717220e+06
# 13    8.563729e+06
# 17    8.404672e+06
# 18    8.130634e+06
# 8     8.128678e+06
# 19    8.073839e+06
# 10    8.037447e+06
# 14    8.006545e+06
# 9     7.879141e+06
# 4     7.794122e+06
# 6     7.697516e+06
# 20    7.636422e+06
# 5     7.539345e+06
# 2     7.527555e+06
# 3     7.149937e+06
# 16    6.976596e+06
# 12    6.670925e+06
# 1     6.419727e+06
# 15    6.311704e+06
# Name: Amount, dtype: float64

# %%
kanin = sales_df.groupby("Member_ID")["Amount"].std().reset_index()
kanin.query("Amount >= 4000")
# Out:
#     Member_ID       Amount
# 9         107  4192.851059
# 17        114  4590.206967
# 20        117  4092.443676
# 32        129  4086.318637
# 90        181  4525.483400
# 94        186  4703.544763
# 104       198  4146.785904
# 113       206  4525.483400
# 116       209  4737.615434
# 128        22  4171.930009
# 133       224  5232.590181
# 137       228  4389.001405
# 145       235  5232.590181
# 156       245  6151.828996
# 157       246  5232.590181
# 161        25  4333.589736
# 200       286  4051.748594
# 204        29  4666.904756
# 207       292  4005.413004
# 212       297  5303.300859
# 258        71  5586.143571
# 263        76  4042.647647
# 281        92  4107.310556

# %%
member_df.groupby("Age")["Member_ID"].count().reset_index().sort_values("Member_ID",ascending=False)
# Out:
#     Age  Member_ID
# 62   80         12
# 12   30         11
# 53   71          9
# 23   41          8
# 31   49          8
# ..  ...        ...
# 20   38          2
# 21   39          1
# 5    23          1
# 35   53          1
# 60   78          1
#
# [63 rows x 2 columns]

# %%
median = member_df["Age"].median()
member_df.query("Age > @median")
# Out:
#     Member_ID  Gender  Age  Days_Since_Registration age_group age_group2
# 0           1    Male   69                      730         D          C
# 2           3    Male   66                     1976         D          C
# 4           5    Male   69                      269         D          A
# 5           6    Male   59                      454         C          B
# 6           7    Male   76                     1889         D          C
# ..        ...     ...  ...                      ...       ...        ...
# 289       290  Female   79                      107         D          A
# 291       292  Female   54                      115         C          A
# 294       295  Female   66                      393         D          B
# 296       297  Female   58                     1613         C          C
# 297       298  Female   71                     1177         D          C
#
# [148 rows x 6 columns]

# %%
sales_df["Amount"].rank(ascending=False)
# Out:
# 0      459.0
# 1      988.0
# 2      916.0
# 3      440.5
# 4       69.5
#        ...
# 995    178.0
# 996    650.0
# 997    797.0
# 998    624.0
# 999    282.0
# Name: Amount, Length: 1000, dtype: float64

# %%
temp = pd.concat([sales_df[["Transaction_ID","Amount"]],sales_df["Amount"].rank(method="first",ascending=False)],axis=1)
temp.columns = ["Transaction_ID", "Amount", "Ranking"]
temp.sort_values(by="Ranking")
# Out:
#     Transaction_ID  Amount  Ranking
# 179            180   10000      1.0
# 199            200   10000      2.0
# 496            497   10000      3.0
# 601            602   10000      4.0
# 653            654   10000      5.0
# ..             ...     ...      ...
# 442            443     500    996.0
# 471            472     500    997.0
# 650            651     500    998.0
# 669            670     500    999.0
# 841            842     500   1000.0
#
# [1000 rows x 3 columns]

# %%
tmp = sales_df.groupby("Member_ID")["Amount"].sum().reset_index()
tmp["Per"] = tmp["Amount"].rank(pct=True)*100
tmp.sort_values(by="Per")
# Out:
#     Member_ID  Amount         Per
# 280        91    1200    0.347222
# 50        145    1300    0.694444
# 169       257    1600    1.041667
# 196       282    1700    1.388889
# 120       212    2000    1.736111
# ..        ...     ...         ...
# 64        158   50200   98.611111
# 60        154   51200   98.958333
# 54        149   51300   99.305556
# 173       260   55100   99.652778
# 235        49   55200  100.000000
#
# [288 rows x 3 columns]

# %%
# kishi_df_df.head()
kategori = pd.pivot_table(kishi_df_df,values="Amount",index="age_group",columns = "Gender",aggfunc="mean")
kategori
# Out:
# C:\Users\rainm\AppData\Local\Temp\ipykernel_24152\846586065.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   kategori = pd.pivot_table(kishi_df_df,values="Amount",index="age_group",columns = "Gender",aggfunc="mean")
# Gender          Female         Male
# age_group
# A          5243.157895  6132.727273
# B          5646.892655  5355.882353
# C          5065.686275  4739.175258
# D          5337.190083  5303.278689

# %%
kishi_df_df.groupby(["age_group","Gender"])["Amount"].mean().reset_index()
# Out:
# C:\Users\rainm\AppData\Local\Temp\ipykernel_24152\671348966.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   kishi_df_df.groupby(["age_group","Gender"])["Amount"].mean().reset_index()
#   age_group  Gender       Amount
# 0         A  Female  5243.157895
# 1         A    Male  6132.727273
# 2         B  Female  5646.892655
# 3         B    Male  5355.882353
# 4         C  Female  5065.686275
# 5         C    Male  4739.175258
# 6         D  Female  5337.190083
# 7         D    Male  5303.278689

# %%
rokugo = pd.pivot_table(kishi_df_df,values="Transaction_ID",index="age_group",columns="Gender",aggfunc="count") 
rokugo.head()
# Out:
# C:\Users\rainm\AppData\Local\Temp\ipykernel_24152\3407995676.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   rokugo = pd.pivot_table(kishi_df_df,values="Transaction_ID",index="age_group",columns="Gender",aggfunc="count")
# Gender     Female  Male
# age_group
# A              95    55
# B             177   170
# C             102    97
# D             121   183

# %%
sales_df["Amount2"] =(sales_df["Amount"] >= 2000).astype(int)
sales_df.head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount Transaction_Date_new  Transaction_Date_month  \
# 0    5800           2024-05-01                       5
# 1     600           2024-05-01                       5
# 2    1300           2024-05-01                       5
# 3    6000           2024-05-01                       5
# 4    9400           2024-05-01                       5
#
#    Transaction_Date_monday  Transaction_Date_week    Per  Amount2
# 0                        2  2024-04-29/2024-05-05  54.20        1
# ...

# %%
hiekin = sales_df["Quantity"].mean()
sales_df["Quantity2"] = (sales_df["Quantity"] >= hiekin).astype(int)
sales_df.head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount Transaction_Date_new  Transaction_Date_month  \
# 0    5800           2024-05-01                       5
# 1     600           2024-05-01                       5
# 2    1300           2024-05-01                       5
# 3    6000           2024-05-01                       5
# 4    9400           2024-05-01                       5
#
#    Transaction_Date_monday  Transaction_Date_week    Per  Amount2  Quantity2
# 0                        2  2024-04-29/2024-05-05  54.20        1          1
# ...

# %%
yumeto = sales_df.groupby("Member_ID")["Amount"].sum().reset_index()
yumeto["Amount3"]= pd.qcut(yumeto["Amount"],q=4,labels=["25%","50%","75%","100%"])
sales_df = sales_df.merge(yumeto[["Member_ID","Amount3"]],on="Member_ID")
sales_df.head()
# Out:
#   Transaction_ID    Transaction_Date Member_ID Product_ID Store_ID  Quantity  \
# 0              1 2024-05-01 00:00:00        21         25       12         3
# 1              2 2024-05-01 02:55:00       107         23       17         1
# 2              3 2024-05-01 05:51:00       117         24        6         3
# 3              4 2024-05-01 08:47:00       124         38        1         3
# 4              5 2024-05-01 11:43:00       281         28        5         4
#
#    Amount Transaction_Date_new  Transaction_Date_month  \
# 0    5800           2024-05-01                       5
# 1     600           2024-05-01                       5
# 2    1300           2024-05-01                       5
# 3    6000           2024-05-01                       5
# 4    9400           2024-05-01                       5
#
#    Transaction_Date_monday  Transaction_Date_week    Per  Amount2  Quantity2  \
# 0                        2  2024-04-29/2024-05-05  54.20        1          1
# ...

# %%
yume = sales_df["Quantity"].sort_values().reset_index()
yume["Quantity5"] = pd.qcut(yume["Quantity"],q=3,labels=["小","中","大"])
yume.head()
# Out:
#    index  Quantity Quantity5
# 0    993         1         小
# 1      1         1         小
# 2    947         1         小
# 3    950         1         小
# 4    951         1         小
